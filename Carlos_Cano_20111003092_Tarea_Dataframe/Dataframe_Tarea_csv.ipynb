# %%
import pandas as pd

df = pd.read_csv('DATA.csv', delimiter=',') # también se puede usar la función read_table

df
# Out:
#        id first_name  last_name                     email  gender  \
# 0       1     Rowney  Pallister    rpallister0@netlog.com    Male
# 1       2    Lynette     Koeppe      lkoeppe1@example.com  Female
# 2       3  Guinevere   Seekings         gseekings2@va.gov  Female
# 3       4     Herold     Snasel           hsnasel3@un.org    Male
# 4       5       Dame     Eveque  deveque4@livejournal.com    Male
# ..    ...        ...        ...                       ...     ...
# 995   996      Dorey        Ody      dodyrn@google.com.br    Male
# 996   997      Karee  Guerreiro    kguerreiroro@google.pl  Female
# 997   998     Lorens      Malek  lmalekrp@liveinternet.ru    Male
# 998   999  Betteanne    Critzen  bcritzenrq@instagram.com  Female
# 999  1000    Estella   Carletto   ecarlettorr@latimes.com  Female
#
#                   address                         career  age  \
# 0       49121 Hallows Way               Graphic Designer   52
# ...

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'address', 'career',
#        'age', 'university', 'city', 'country', 'ratings'],
#       dtype='object')

# %%
df[['first_name','gender']]
# Out:
#     first_name  gender
# 0       Rowney    Male
# 1      Lynette  Female
# 2    Guinevere  Female
# 3       Herold    Male
# 4         Dame    Male
# ..         ...     ...
# 995      Dorey    Male
# 996      Karee  Female
# 997     Lorens    Male
# 998  Betteanne  Female
# 999    Estella  Female
#
# [1000 rows x 2 columns]

# %%
df
# Out:
#        id first_name  last_name                     email  gender  \
# 0       1     Rowney  Pallister    rpallister0@netlog.com    Male
# 1       2    Lynette     Koeppe      lkoeppe1@example.com  Female
# 2       3  Guinevere   Seekings         gseekings2@va.gov  Female
# 3       4     Herold     Snasel           hsnasel3@un.org    Male
# 4       5       Dame     Eveque  deveque4@livejournal.com    Male
# ..    ...        ...        ...                       ...     ...
# 995   996      Dorey        Ody      dodyrn@google.com.br    Male
# 996   997      Karee  Guerreiro    kguerreiroro@google.pl  Female
# 997   998     Lorens      Malek  lmalekrp@liveinternet.ru    Male
# 998   999  Betteanne    Critzen  bcritzenrq@instagram.com  Female
# 999  1000    Estella   Carletto   ecarlettorr@latimes.com  Female
#
#                   address                         career  age  \
# 0       49121 Hallows Way               Graphic Designer   52
# ...
